# %%
import src.parser

# %%
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator
from rdkit.Chem.Draw import IPythonConsole
from rdkit import DataStructs
import rdkit
print(rdkit.__version__)
# %pylab inline
# Out:
# 2024.03.5
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# get current working directiory
import os
os.getcwd()
# Out:
# '/Users/cgu3/Documents/experiments/knext/notebooks'

# %%
ms = [x for x in Chem.SmilesMolSupplier('../data/BLSets_selected_actives.txt') if x.GetProp('_Name')=='CHEMBL204']
ms[0]

# %%
mol = Chem.MolFromSmiles('Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)(O)OP(=O)(O)OP(=O)(O)O)[C@@H](O)[C@H]1O')
print(mol)

# %%
rdkgen = rdFingerprintGenerator.GetRDKitFPGenerator(fpSize=1024)

# %%
rdkfp = rdkgen.GetFingerprint(mol)

# %%
rdkfp
# Out:
# 1
